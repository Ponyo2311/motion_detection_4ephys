# %%
import os
import glob
import numpy as np

# %%
fileTree={"name":["Dax","Odo","Timon","Pumba"]}
fileTree["data_number"]=["data-116","data-117"]

# %%
sessions={}
toConvert=[]
for i in fileTree["data_number"]:
    for j in fileTree["name"]:
        path=os.path.join("/media/",i,j)
        if os.path.exists(path):
            sessions[j]={"data_nb":i,
                         "rat_name":j,
                         "dat2convert":[f for f in glob.glob(path+"*/**/Neuropix-PXI-100.1/*.dat", 
                                                 recursive=True) if os.path.isfile(f)],
                         "dat2convert_2":[f for f in glob.glob(path+"*/**/Neuropix-PXI-100.3/*.dat", 
                                                 recursive=True) if os.path.isfile(f)]}
            toConvert.append(sessions[j]["dat2convert"])
            toConvert.append(sessions[j]["dat2convert_2"])

# %%
toConvert
# Out:
# [['/media/data-116/Dax/1.Data/2021-05-25_12-32-00/Record Node 102/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.dat'],
#  [],
#  ['/media/data-116/Odo/1.Data/2021-06-01_11-36-30/Record Node 101/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.dat',
#   '/media/data-116/Odo/1.Data/2021-06-03_10-30-45/Record Node 101/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.dat',
#   '/media/data-116/Odo/1.Data/2021-06-02_11-35-31/Record Node 101/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.dat',
#   '/media/data-116/Odo/1.Data/2021-05-31_15-41-39/Record Node 101/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.dat',
#   '/media/data-116/Odo/1.Data/2021-06-01_10-29-22/Record Node 101/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.dat'],
#  [],
#  ['/media/data-116/Timon/1. Data/2021-03-16_21-36-41/Record Node 101/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.dat',
# ...

# %%
toConvert=np.concatenate(toConvert)

# %%
len(toConvert)
# Out:
# 41

# %%
toConvert
# Out:
# array(['/media/data-116/Dax/1.Data/2021-05-25_12-32-00/Record Node 102/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.dat',
#        '/media/data-116/Odo/1.Data/2021-06-01_11-36-30/Record Node 101/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.dat',
#        '/media/data-116/Odo/1.Data/2021-06-03_10-30-45/Record Node 101/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.dat',
#        '/media/data-116/Odo/1.Data/2021-06-02_11-35-31/Record Node 101/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.dat',
#        '/media/data-116/Odo/1.Data/2021-05-31_15-41-39/Record Node 101/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.dat',
#        '/media/data-116/Odo/1.Data/2021-06-01_10-29-22/Record Node 101/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.dat',
# ...

# %%
for filepath in toConvert:
    # !process_extractchannels filepath "${i::-14}cam_ref_chan_2500Hz.dat" 385 384
    # !process_resample -f 2500,1250 -n 385 "${i}" "${i::-3}eeg"

# %%
"{}cam_ref_chan_2500Hz.dat".format(toConvert[0][0:-14])
# Out:
# '/media/data-116/Dax/1.Data/2021-05-25_12-32-00/Record Node 102/experiment1/recording1/continuous/Neuropix-PXI-100.1/cam_ref_chan_2500Hz.dat'

# %%
for filepath in toConvert:
    path2put="'{}'".format(filepath[:-14]+"cam_ref_chan_2500Hz.dat")
    fp="'{}'".format(filepath)
    eeg="'{}'".format(filepath[:-3]+"eeg")
    # !process_extractchannels $fp $path2put 385 384
    # !process_resample -f 2500,1250 -n 385 $fp $eeg
# Out:
# /media/data-116/Dax/1.Data/2021-05-25_12-32-00/Record Node 102/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.dat (1/385 channels) 0% .................................................. 100##################################################
# Input File     : /media/data-116/Dax/1.Data/2021-05-25_12-32-00/Record Node 102/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.dat
# Channels       : 385
# Sampling Rate  : 2500.000000
# Output file    : /media/data-116/Dax/1.Data/2021-05-25_12-32-00/Record Node 102/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.eeg
# Sampling Rate  : 1250.000000
# Freq Ratio     : 0.500000
# Converter      : Fastest Sinc Interpolator
# Resampling     : 0% .................................................. 100##################################################
# Output Frames  : 53989606
# ...

# %%
for filepath in toConvert:
    path2put="'{}'".format(filepath[:-14])
    # !ls -a $path2put
# Out:
# ls: cannot access '/media/data-102/2021-07-15_18-55-38/Record Node 101/experiment1/recording1/continuous/Neuropix-PXI-100.1/': No such file or directory
# ls: cannot access '/media/data-102/2021-07-14_12-24-22/Record Node 101/experiment1/recording1/continuous/Neuropix-PXI-100.1/': No such file or directory
# ls: cannot access '/media/data-102/2021-07-14_21-20-16/Record Node 101/experiment1/recording1/continuous/Neuropix-PXI-100.1/': No such file or directory
# ls: cannot access '/media/data-102/2021-07-16_17-43-44/Record Node 101/experiment1/recording1/continuous/Neuropix-PXI-100.1/': No such file or directory
# ls: cannot access '/media/data-102/2021-07-17_07-09-45/Record Node 101/experiment1/recording1/continuous/Neuropix-PXI-100.1/': No such file or directory
# ls: cannot access '/media/data-102/2021-07-17_19-31-19/Record Node 101/experiment1/recording1/continuous/Neuropix-PXI-100.1/': No such file or directory
# ...

# %% [markdown]
# ## MAEVA's 628 & 627

# %%
paths=["/media/data-102/","/media/data-101/"]
path="/media/data-102/"
#101 is already done

# %%
sessions={}
toConvert=[]

#for path in paths[0]:
sessions={
             "dat2convert":[f for f in glob.glob(path+"*/**/Neuropix-PXI-100.1/*.dat", 
                                     recursive=True) if os.path.isfile(f)],
             "dat2convert_2":[f for f in glob.glob(path+"*/**/Neuropix-PXI-100.3/*.dat", 
                                     recursive=True) if os.path.isfile(f)]}
toConvert.append(sessions["dat2convert"])
toConvert.append(sessions["dat2convert_2"])

# %%
toConvert
# Out:
# [['/media/data-102/2021-07-15_18-55-38/Record Node 101/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.dat',
#   '/media/data-102/2021-07-14_12-24-22/Record Node 101/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.dat',
#   '/media/data-102/2021-07-14_21-20-16/Record Node 101/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.dat',
#   '/media/data-102/2021-07-16_17-43-44/Record Node 101/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.dat',
#   '/media/data-102/2021-07-17_07-09-45/Record Node 101/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.dat',
#   '/media/data-102/2021-07-17_19-31-19/Record Node 101/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.dat',
#   '/media/data-102/2021-07-15_11-48-54/Record Node 101/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.dat',
# ...

# %%
toConvert=np.concatenate(toConvert)

# %%
len(toConvert)
# Out:
# 17

# %%
toConvert
# Out:
# array(['/media/data-102/2021-07-15_18-55-38/Record Node 101/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.dat',
#        '/media/data-102/2021-07-14_12-24-22/Record Node 101/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.dat',
#        '/media/data-102/2021-07-14_21-20-16/Record Node 101/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.dat',
#        '/media/data-102/2021-07-16_17-43-44/Record Node 101/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.dat',
#        '/media/data-102/2021-07-17_07-09-45/Record Node 101/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.dat',
#        '/media/data-102/2021-07-17_19-31-19/Record Node 101/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.dat',
#        '/media/data-102/2021-07-15_11-48-54/Record Node 101/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.dat',
# ...

# %%
for filepath in toConvert:
    # !process_extractchannels filepath "${i::-14}cam_ref_chan_2500Hz.dat" 385 384
    # !process_resample -f 2500,1250 -n 385 "${i}" "${i::-3}eeg"

# %%
"{}cam_ref_chan_2500Hz.dat".format(toConvert[0][0:-14])
# Out:
# '/media/data-116/Dax/1.Data/2021-05-25_12-32-00/Record Node 102/experiment1/recording1/continuous/Neuropix-PXI-100.1/cam_ref_chan_2500Hz.dat'

# %% [markdown]
# ## Take out empty spaces from folders

# %%
#list folders with empty spaces and rename them
folders = [i for i in glob.glob(path+"*/Record*")]
for folder in folders:
    r = folder.replace(" ","")
    if( r != folder):
        # try:
        os.rename(folder,r)
            # print("done")
        # except FileNotFoundError:
        #     pass

# %%
for filepath in toConvert:
    filepath = filepath.replace(" ","")
    path2put="'{}'".format(filepath[:-14]+"cam_ref_chan_2500Hz.dat")
    fp="'{}'".format(filepath)
    eeg="'{}'".format(filepath[:-3]+"eeg")
    # !process_extractchannels $fp $path2put 385 384
    # !process_resample -f 2500,1250 -n 385 $fp $eeg
# Out:
# /media/data-102/2021-07-15_18-55-38/RecordNode101/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.dat (1/385 channels) 0% .................................................. 100##################################################
# Input File     : /media/data-102/2021-07-15_18-55-38/RecordNode101/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.dat
# Channels       : 385
# Sampling Rate  : 2500.000000
# Output file    : /media/data-102/2021-07-15_18-55-38/RecordNode101/experiment1/recording1/continuous/Neuropix-PXI-100.1/continuous.eeg
# Sampling Rate  : 1250.000000
# Freq Ratio     : 0.500000
# Converter      : Fastest Sinc Interpolator
# Resampling     : 0% .................................................. 100##################################################
# Output Frames  : 65024523
# ...

# %%
for filepath in toConvert:
    path2put="'{}'".format(filepath[:-14])
    # !ls -a $path2put
# Out:
# .  ..  continuous.dat  synchronized_timestamps.npy  timestamps.npy
# .  ..  continuous.dat  synchronized_timestamps.npy  timestamps.npy
# .  ..  continuous.dat  synchronized_timestamps.npy  timestamps.npy
# .  ..  continuous.dat  synchronized_timestamps.npy  timestamps.npy
# .   continuous.dat  continuous.xml		 timestamps.npy
# ..  continuous.nrs  synchronized_timestamps.npy
# .  ..  continuous.dat  synchronized_timestamps.npy  timestamps.npy
# .  ..  continuous.dat  synchronized_timestamps.npy  timestamps.npy
# .  ..  continuous.dat  synchronized_timestamps.npy  timestamps.npy
# .  ..  continuous.dat  synchronized_timestamps.npy  timestamps.npy
# .  ..  continuous.dat  synchronized_timestamps.npy  timestamps.npy
# .  ..  continuous.dat  synchronized_timestamps.npy  timestamps.npy
# .  ..  continuous.dat  synchronized_timestamps.npy  timestamps.npy
# .  ..  continuous.dat  synchronized_timestamps.npy  timestamps.npy
# ...
