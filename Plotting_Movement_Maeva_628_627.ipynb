# %% [markdown]
# # **Notes**
#
# + Info about rat positions on the video and recording channels
#     + w628 -> Neuropix 0 & 1; RIGHT on the video
#     + w627 -> Neuropix 2 & 3; LEFT on the video (cf stickers on the vid)
#     <br>
#     <br>
# + Remarque on precising path to package: <br>
#     + *vpp* contains 2 packages: *video_processing* & *utils*. <br>
#     + In this notebook we will use functions form modules in *utils*. To import these modules we need to add path to *vpp* folder to th paths where python will look for imports.
#     + It is possible to verify that folder we need is within the considered paths with **sys.path** command

# %%
import os
import sys
sys.path.append(os.path.join(os.getcwd(),"vpp"))

# %%
from utils import plot_mvm, mvm2txt, chopOffTail, rescalingNOF

# %% [markdown]
# # RAT 1 a.k.a. W628

# %%
w628 = "/media/data-119/Rat628-20210714/"

# %% [markdown]
# ## session 1 of 14th of July

# %%
plot_mvm(path = os.path.join(w628, "acA1300-60gmNIR__21471690__20210714_122428913.csv"),
             resample_freq = '1S', #you can set resampling freq: '1T' for 1 minute
             plot_all =True,
             start={"hours": 2, "minutes": 0, "seconds": 0},
             dt={"hours": 1, "minutes": 0, "seconds": 0},
             ylim=1,
             save=False)
# Out:
# Index(['frame_nb', 'millisec', 'mvm_rat1', 'mvm_rat2', 'mvmr1_normalized',
#        'mvmr2_normalized'],
#       dtype='object')

# %%
plot_mvm(path = os.path.join(w628, "acA1300-60gmNIR__21471690__20210714_122428913.csv"),
             resample_freq = '1S', #you can set resampling freq: '1T' for 1 minute
             plot_all = False,
             start={"hours": 1, "minutes": 25, "seconds": 0},
             dt={"hours": 0, "minutes": 10, "seconds": 0},
             ylim=1,
             save=False)
# Out:
# Index(['frame_nb', 'millisec', 'mvm_rat1', 'mvm_rat2', 'mvmr1_normalized',
#        'mvmr2_normalized'],
#       dtype='object')

# %% [markdown]
# ### Saving movement var in txt file

# %%
mvm2txt(os.path.join(w628, "acA1300-60gmNIR__21471690__20210714_122428913.csv"),
        rat=1)
# Out:
# /media/data-119/Rat628-20210714
# /media/data-119/Rat628-20210714/Rat628-20210714mvm.txt

# %%
rescalingNOF(path2ephysTime = os.path.join(w628, "Rat628-20210714_1tmstp_sec.txt"),
             path2mvm = os.path.join(w628, "Rat628-20210714_1mvm.txt"),
             path2duration = os.path.join(w628, "Rat628-20210714_1duration.txt"))
# Out:
# 202 frames were deleted.

# %% [markdown]
# ## session 2 of 14th of July

# %%
plot_mvm(path = os.path.join(w628, "acA1300-60gmNIR__21471690__20210714_212500309.csv"),
             resample_freq = '1S', #you can set resampling freq: '1T' for 1 minute
             plot_all = True,
             start={"hours": 2, "minutes": 0, "seconds": 0},
             dt={"hours": 1, "minutes": 0, "seconds": 0},
             ylim=1,
             save=False)
# Out:
# Index(['frame_nb', 'millisec', 'mvm_rat1', 'mvm_rat2', 'mvmr1_normalized',
#        'mvmr2_normalized'],
#       dtype='object')

# %%
plot_mvm(path = os.path.join(w628, "acA1300-60gmNIR__21471690__20210714_212500309.csv"),
             resample_freq = '1S', #you can set resampling freq: '1T' for 1 minute
             plot_all = False,
             start={"hours": 1, "minutes": 25, "seconds": 0},
             dt={"hours": 0, "minutes": 10, "seconds": 0},
             ylim=1,
             save=False)
# Out:
# Index(['frame_nb', 'millisec', 'mvm_rat1', 'mvm_rat2', 'mvmr1_normalized',
#        'mvmr2_normalized'],
#       dtype='object')

# %% [markdown]
# ### Saving movement var in txt file

# %%
mvm2txt(os.path.join(w628, "acA1300-60gmNIR__21471690__20210714_212500309.csv"),
        path2vid = os.path.join(w628, "Rat628-20210714_2.mp4"),
        path2ephysTime = os.path.join(w628, "Rat628-20210714_2tmstp_sec.txt"),
        rat=1)
# Out:
# Video duration: 45407.28
# Sum of diffs: 45395.686.
# Video signal is 11.593999999997322 seconds longer than sync_file, which corresponds to 289 number of frames

# %% [markdown]
# ### Rescaling number of frames

# %%
rescalingNOF(path2ephysTime = os.path.join(w628, "Rat628-20210714_2tmstp_sec.txt"),
             path2mvm = os.path.join(w628, "Rat628-20210714_2mvm.txt"),
             path2duration = os.path.join(w628, "Rat628-20210714_2duration.txt"))
# Out:
# 298 frames were deleted.
